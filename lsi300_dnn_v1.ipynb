# %% [markdown]
# ## NN Classifier over LSI Features
# In this notebook, we train a neural network over LSI features. We use the
# Keras wrapper for Theano, which is a deep learning library. We also use cuDNN library to train the neural networks over a 640 core GPU.

# %%
from keras.models import Sequential
from keras.layers import Dense
import numpy as np
import pandas as pd
from sklearn.model_selection import train_test_split
# Out:
# Using Theano backend.
# Using cuDNN version 5110 on context None
# Mapped name None to device cuda0: GeForce GTX 750 Ti (0000:01:00.0)

# %%
topics_filename = 'lsi_data300b_all.csv'
train_filename = 'train.csv'
data_ncol = 600

# %%
df = pd.read_csv(topics_filename, header=None)
df = df.drop(data_ncol,1)
df.head()
# Out:
#         0         1         2         3         4         5         6    \
# 0  0.131042  0.096003 -0.195274  0.469180  0.763645  0.066793 -0.021648
# 1  0.009245  0.005745 -0.004329 -0.000550 -0.001873 -0.000079  0.009881
# 2  0.051079  0.159673  0.002976  0.059459  0.006203  0.558757 -0.299178
# 3  0.002646  0.004533  0.000547 -0.000175  0.001089  0.002622 -0.001468
# 4  0.003509  0.005099 -0.003794  0.001574  0.001012  0.005732 -0.001807
#
#         7         8         9      ...          590       591       592  \
# 0 -0.257048 -0.130603  0.022374    ...    -0.011592  0.027450 -0.008152
# 1  0.004697 -0.004561 -0.003011    ...    -0.013837 -0.000945 -0.011689
# 2  0.587733 -0.301212  0.129429    ...    -0.025035 -0.041846  0.005580
# 3 -0.000800 -0.001137  0.001742    ...     0.000964 -0.005293 -0.001525
# 4  0.004340 -0.001001  0.002139    ...     0.017485 -0.030173 -0.010787
#
#         593       594       595       596       597       598       599
# 0  0.010548  0.009167  0.030231  0.021670 -0.011562 -0.028943  0.003201
# 1  0.027448 -0.007048  0.008755 -0.002345  0.009492  0.009700 -0.008459
# 2 -0.060296  0.028666  0.055619 -0.002305  0.064361  0.013166  0.049409
# 3  0.002722 -0.005545 -0.003712  0.000462 -0.003276 -0.002065 -0.004547
# 4 -0.006813  0.015261 -0.004887  0.000673 -0.018812 -0.009162  0.020759
#
# [5 rows x 600 columns]

# %%
df.shape
# Out:
# (404290, 600)

# %%
df_text = pd.read_csv(train_filename).fillna("")
df_text.head()
# Out:
#    id  qid1  qid2                                          question1  \
# 0   0     1     2  What is the step by step guide to invest in sh...
# 1   1     3     4  What is the story of Kohinoor (Koh-i-Noor) Dia...
# 2   2     5     6  How can I increase the speed of my internet co...
# 3   3     7     8  Why am I mentally very lonely? How can I solve...
# 4   4     9    10  Which one dissolve in water quikly sugar, salt...
#
#                                            question2  is_duplicate
# 0  What is the step by step guide to invest in sh...             0
# 1  What would happen if the Indian government sto...             0
# 2  How can Internet speed be increased by hacking...             0
# 3  Find the remainder when [math]23^{24}[/math] i...             0
# 4            Which fish would survive in salt water?             0

# %%
print df_text.shape
print df.shape
# Out:
# (404290, 6)
# (404290, 600)

# %%
X = df.values
y = df_text.iloc[:,-1:].values.ravel()
del df_text

# %%
seed = 7
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.33, random_state=seed)

# %%
from sklearn.model_selection import StratifiedKFold
from keras.callbacks import ModelCheckpoint

# %% [markdown]
# #### Build, Train and Verify
# We build a neural network model and train it over a predecided portion of the dataset while simultaneously verifying it over another predecided test dataset. We also save the weights corresponding to the best accuracy achieved over the the test set, during the learning process. Later, we use these weights to evaluate the performance of the best trained network.

# %%
#create model
model = Sequential()
model.add(Dense(600, input_dim=600, kernel_initializer='uniform', activation='relu'))
model.add(Dense(600, kernel_initializer='uniform', activation='relu'))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
# checkpoint 
filepath='weights.best.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc' , verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(X_train, y_train, validation_data=(X_test,y_test), epochs=20, callbacks=callbacks_list, batch_size=10000)
# Out:
# Train on 270874 samples, validate on 133416 samples
# Epoch 1/20
# Epoch 00000: val_acc improved from -inf to 0.67143, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 3s - loss: 0.6332 - acc: 0.6328 - val_loss: 0.6028 - val_acc: 0.6714
# Epoch 2/20
# Epoch 00001: val_acc improved from 0.67143 to 0.70158, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5917 - acc: 0.6917 - val_loss: 0.5724 - val_acc: 0.7016
# Epoch 3/20
# Epoch 00002: val_acc improved from 0.70158 to 0.71589, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5529 - acc: 0.7091 - val_loss: 0.5418 - val_acc: 0.7159
# Epoch 4/20
# Epoch 00003: val_acc improved from 0.71589 to 0.72277, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5232 - acc: 0.7266 - val_loss: 0.5285 - val_acc: 0.7228
# Epoch 5/20
# Epoch 00004: val_acc improved from 0.72277 to 0.72785, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5025 - acc: 0.7394 - val_loss: 0.5217 - val_acc: 0.7279
# Epoch 6/20
# Epoch 00005: val_acc improved from 0.72785 to 0.73098, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.4852 - acc: 0.7499 - val_loss: 0.5200 - val_acc: 0.7310
# Epoch 7/20
# Epoch 00006: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4690 - acc: 0.7599 - val_loss: 0.5220 - val_acc: 0.7303
# Epoch 8/20
# Epoch 00007: val_acc improved from 0.73098 to 0.73382, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.4564 - acc: 0.7675 - val_loss: 0.5212 - val_acc: 0.7338
# Epoch 9/20
# Epoch 00008: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4438 - acc: 0.7748 - val_loss: 0.5247 - val_acc: 0.7313
# Epoch 10/20
# Epoch 00009: val_acc improved from 0.73382 to 0.73694, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.4301 - acc: 0.7822 - val_loss: 0.5308 - val_acc: 0.7369
# Epoch 11/20
# Epoch 00010: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4195 - acc: 0.7874 - val_loss: 0.5321 - val_acc: 0.7352
# Epoch 12/20
# Epoch 00011: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4096 - acc: 0.7931 - val_loss: 0.5374 - val_acc: 0.7333
# Epoch 13/20
# Epoch 00012: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4027 - acc: 0.7973 - val_loss: 0.5432 - val_acc: 0.7352
# Epoch 14/20
# Epoch 00013: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3933 - acc: 0.8026 - val_loss: 0.5474 - val_acc: 0.7349
# Epoch 15/20
# Epoch 00014: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3851 - acc: 0.8059 - val_loss: 0.5711 - val_acc: 0.7352
# Epoch 16/20
# Epoch 00015: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3805 - acc: 0.8084 - val_loss: 0.5656 - val_acc: 0.7349
# Epoch 17/20
# Epoch 00016: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3732 - acc: 0.8126 - val_loss: 0.5659 - val_acc: 0.7315
# Epoch 18/20
# Epoch 00017: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3662 - acc: 0.8162 - val_loss: 0.5720 - val_acc: 0.7321
# Epoch 19/20
# Epoch 00018: val_acc improved from 0.73694 to 0.73942, saving model to weights.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.3591 - acc: 0.8200 - val_loss: 0.5810 - val_acc: 0.7394
# Epoch 20/20
# Epoch 00019: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.3569 - acc: 0.8229 - val_loss: 0.5879 - val_acc: 0.7316

# %%
import matplotlib.pyplot as plt
# %matplotlib inline

# %% [markdown]
# #### Plotting Accuracy History
# We plot the history of accuracy during the training of the neural network for both the training and test set. We observe that while the accuracy continues to grow for the training set, it saturates for the test set. This can be interpreted as overfitting the training portion.

# %%
# summarize history for accuracy
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# #### Performance Evaluation

# %%
from sklearn.metrics import roc_curve, auc
# %matplotlib inline

# %%
from sklearn.metrics import accuracy_score
from sklearn.metrics import precision_recall_curve
from sklearn.metrics import average_precision_score
from sklearn.metrics import confusion_matrix

# %% [markdown]
# ##### ROC Curve over Test Set

# %%
# load weights
model.load_weights("weights.best.hdf5")
y_pred_prob = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 132960/133416 [============================>.] - ETA: 0s

# %% [markdown]
# ##### ROC Curve over Training Set

# %%
# load weights
model.load_weights("weights.best.hdf5")
y_pred_prob_tr = model.predict_proba(X_train)
fpr, tpr, thresholds = roc_curve(y_train, y_pred_prob_tr)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 268864/270874 [============================>.] - ETA: 0s

# %%
print y_test.shape
print y_pred_prob.shape
# Out:
# (133416L,)
# (133416L, 1L)

# %% [markdown]
# ##### Precision Recall Curve over Test Set

# %%
precision = dict()
recall = dict()
average_precision = dict()
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
average_precision = average_precision_score(y_test, y_pred_prob)

# Plot Precision-Recall curve
plt.plot(recall, precision, lw=2, color='navy',
         label='Precision-Recall curve for ')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Non Default: AUC={0:0.2f}'.format(average_precision))
plt.legend(loc="lower left")
plt.show()

# %% [markdown]
# ##### Confusion Matrix

# %%
y_pred = model.predict_classes(X_test).ravel()
# Out:
# 130784/133416 [============================>.] - ETA: 0s

# %%
print confusion_matrix(y_test, y_pred)
# Out:
# [[71792 12414]
#  [22352 26858]]

# %% [markdown]
# #### Find Average Accuracy with 10-Fold Crossvalidation
# Here, we use the StratifiedKFold class from the scikit-learn to split up the training dataset into 10 folds. The folds are stratiﬁed, meaning that the algorithm attempts to balance the number of instances of each class in each fold. The example creates and evaluates 10 models using the 10 splits of the data and collects all of the scores. The verbose output for each epoch is turned off by passing verbose=0 to the fit() and evaluate() functions on the model. The performance is printed for each model and it is stored. The average and standard deviation of the model performance is then printed at the end of the run to provide a robust estimate of model accuracy.

# %%
np.random.seed(seed)
kfold = StratifiedKFold(n_splits=10, shuffle=True, random_state=seed)
cvscores = []
for train, test in kfold.split(X, y):
  # create model
    model = Sequential()
    model.add(Dense(600, input_dim=600, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(600, kernel_initializer='uniform', activation='relu'))
    model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
    # Compile model
    model.compile(loss='binary_crossentropy', optimizer='adam', metrics=['accuracy'])
    # Fit the model
    model.fit(X[train], y[train], epochs=10, batch_size=10000, verbose=0)
    # evaluate the model
    scores = model.evaluate(X[test], y[test], verbose=0)
    print("%s: %.2f%%" % (model.metrics_names[1], scores[1]*100))
    cvscores.append(scores[1] * 100)

print("%.2f%% (+/- %.2f%%)" % (np.mean(cvscores), np.std(cvscores)))
# Out:
# acc: 74.41%
# acc: 73.95%
# acc: 73.84%
# acc: 74.29%
# acc: 73.88%
# acc: 73.98%
# acc: 74.12%
# acc: 73.97%
# acc: 74.49%
# acc: 74.20%
# 74.11% (+/- 0.21%)

# %% [markdown]
# ### Employing Dropout
# We experiment with dropout by inserting dropout in the input and deep layers.
# We see that we get some improvement in the ROC area under the curve by using the drop out, which means slightly better prediction performance and less overfitting.

# %%
from keras.constraints import maxnorm
from keras.optimizers import SGD
from keras.layers import Dropout

# %%
#create model
model = Sequential()
model.add(Dropout(0.2, input_shape=(600,)))
model.add(Dense(600, input_dim=600, kernel_initializer='uniform', 
                activation='relu',  kernel_constraint=maxnorm(2.)))
model.add(Dropout(0.2))
model.add(Dense(600, kernel_initializer='uniform', activation='relu',
                kernel_constraint=maxnorm(2.)))
model.add(Dropout(0.2))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
#sgd = SGD(lr=1.0, momentum=0.9, decay=0.001, nesterov=True)
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])
# checkpoint 
filepath='weights_do.best.hdf5'
checkpoint = ModelCheckpoint(filepath, monitor='val_acc' , verbose=1, save_best_only=True, mode='max')
callbacks_list = [checkpoint]
history = model.fit(X_train, y_train, epochs=20, validation_data=(X_test,y_test), batch_size=10000, callbacks=callbacks_list)
# Out:
# Train on 270874 samples, validate on 133416 samples
# Epoch 1/20
# Epoch 00000: val_acc improved from -inf to 0.65946, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 3s - loss: 0.6377 - acc: 0.6290 - val_loss: 0.6069 - val_acc: 0.6595
# Epoch 2/20
# Epoch 00001: val_acc improved from 0.65946 to 0.69901, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.6062 - acc: 0.6749 - val_loss: 0.5887 - val_acc: 0.6990
# Epoch 3/20
# Epoch 00002: val_acc improved from 0.69901 to 0.70737, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5830 - acc: 0.6916 - val_loss: 0.5566 - val_acc: 0.7074
# Epoch 4/20
# Epoch 00003: val_acc improved from 0.70737 to 0.71555, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5596 - acc: 0.7028 - val_loss: 0.5414 - val_acc: 0.7156
# Epoch 5/20
# Epoch 00004: val_acc improved from 0.71555 to 0.71974, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5448 - acc: 0.7119 - val_loss: 0.5314 - val_acc: 0.7197
# Epoch 6/20
# Epoch 00005: val_acc improved from 0.71974 to 0.72346, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5357 - acc: 0.7177 - val_loss: 0.5273 - val_acc: 0.7235
# Epoch 7/20
# Epoch 00006: val_acc improved from 0.72346 to 0.72495, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5277 - acc: 0.7233 - val_loss: 0.5238 - val_acc: 0.7250
# Epoch 8/20
# Epoch 00007: val_acc improved from 0.72495 to 0.72625, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 3s - loss: 0.5211 - acc: 0.7270 - val_loss: 0.5222 - val_acc: 0.7263
# Epoch 9/20
# Epoch 00008: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.5159 - acc: 0.7304 - val_loss: 0.5225 - val_acc: 0.7242
# Epoch 10/20
# Epoch 00009: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.5119 - acc: 0.7332 - val_loss: 0.5200 - val_acc: 0.7256
# Epoch 11/20
# Epoch 00010: val_acc improved from 0.72625 to 0.72739, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.5071 - acc: 0.7347 - val_loss: 0.5178 - val_acc: 0.7274
# Epoch 12/20
# Epoch 00011: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.5028 - acc: 0.7364 - val_loss: 0.5187 - val_acc: 0.7273
# Epoch 13/20
# Epoch 00012: val_acc improved from 0.72739 to 0.73029, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.4992 - acc: 0.7388 - val_loss: 0.5147 - val_acc: 0.7303
# Epoch 14/20
# Epoch 00013: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4963 - acc: 0.7411 - val_loss: 0.5147 - val_acc: 0.7296
# Epoch 15/20
# Epoch 00014: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4924 - acc: 0.7442 - val_loss: 0.5167 - val_acc: 0.7279
# Epoch 16/20
# Epoch 00015: val_acc improved from 0.73029 to 0.73262, saving model to weights_do.best.hdf5
# 270874/270874 [==============================] - 2s - loss: 0.4900 - acc: 0.7446 - val_loss: 0.5097 - val_acc: 0.7326
# Epoch 17/20
# Epoch 00016: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4865 - acc: 0.7464 - val_loss: 0.5130 - val_acc: 0.7294
# Epoch 18/20
# Epoch 00017: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4839 - acc: 0.7483 - val_loss: 0.5101 - val_acc: 0.7320
# Epoch 19/20
# Epoch 00018: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4825 - acc: 0.7482 - val_loss: 0.5105 - val_acc: 0.7318
# Epoch 20/20
# Epoch 00019: val_acc did not improve
# 270874/270874 [==============================] - 2s - loss: 0.4803 - acc: 0.7496 - val_loss: 0.5101 - val_acc: 0.7313

# %% [markdown]
# ##### Accuracy of History during Training

# %%
plt.plot(history.history['acc'])
plt.plot(history.history['val_acc'])
plt.title('model accuracy')
plt.ylabel('accuracy')
plt.xlabel('epoch')
plt.legend(['train', 'test'], loc='upper left')
plt.show()

# %% [markdown]
# ##### ROC Curve for Test Set

# %%
# load weights
model.load_weights("weights_do.best.hdf5")
y_pred_prob = model.predict_proba(X_test)
fpr, tpr, thresholds = roc_curve(y_test, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 132512/133416 [============================>.] - ETA: 0s

# %% [markdown]
# For the LSI features we do not find any improvement in the area under the ROC curve using dropout.

# %% [markdown]
# ##### ROC Curve for Training Set

# %%
y_pred_prob = model.predict_proba(X_train)
fpr, tpr, thresholds = roc_curve(y_train, y_pred_prob)
roc_auc = auc(fpr, tpr)

plt.figure()
lw = 2
plt.plot(fpr, tpr, color='darkorange',
         lw=lw, label='ROC curve (area = %0.2f)' % roc_auc)
plt.plot([0, 1], [0, 1], color='navy', lw=lw, linestyle='--')
plt.xlim([0.0, 1.0])
plt.ylim([0.0, 1.05])
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.title('Receiver operating characteristic')
plt.legend(loc="lower right")
plt.show()
# Out:
# 269952/270874 [============================>.] - ETA: 0s

# %% [markdown]
# We do see a decrease in the area under the ROC of 0.04, which means that the model complexity has been reduced as compared to without dropout.

# %% [markdown]
# ##### Precision Recall Curve over Test Set

# %%
model = Sequential()
model.add(Dropout(0.2, input_shape=(600,)))
model.add(Dense(600, input_dim=600, kernel_initializer='uniform', 
                activation='relu',  kernel_constraint=maxnorm(2.)))
model.add(Dropout(0.2))
model.add(Dense(600, kernel_initializer='uniform', activation='relu',
                kernel_constraint=maxnorm(2.)))
model.add(Dropout(0.2))
model.add(Dense(1, kernel_initializer='uniform', activation='sigmoid'))
#model.load_weights("weights_do.best.hdf5")
model.compile(loss='binary_crossentropy', optimizer='Adam', metrics=['accuracy'])

# %%
model.load_weights("weights_do.best.hdf5")
y_pred_prob = model.predict_proba(X_test)
# Out:
# 132896/133416 [============================>.] - ETA: 0s

# %% [markdown]
# ##### Precision Recall Curve over Test Set

# %%
precision = dict()
recall = dict()
average_precision = dict()
precision, recall, _ = precision_recall_curve(y_test, y_pred_prob)
average_precision = average_precision_score(y_test, y_pred_prob)

# Plot Precision-Recall curve
plt.plot(recall, precision, lw=2, color='navy',
         label='Precision-Recall curve for ')
plt.xlabel('Recall')
plt.ylabel('Precision')
plt.ylim([0.0, 1.05])
plt.xlim([0.0, 1.0])
plt.title('Precision-Recall Non Default: AUC={0:0.2f}'.format(average_precision))
plt.legend(loc="lower left")
plt.show()

# %%
y_pred = model.predict_classes(X_test).ravel()
# Out:
# 132000/133416 [============================>.] - ETA: 0s

# %% [markdown]
# ##### Confusion Matrix

# %%
print confusion_matrix(y_test, y_pred)
# Out:
# [[68801 15405]
#  [20268 28942]]

# %% [markdown]
# We see that the recall of the duplicate class has improved a little bit, while there is drop in the recall of the non-duplicate class.
